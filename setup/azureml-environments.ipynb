# %%
from azureml.core import Workspace
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# azureml
# azureml
# japaneast
# 82a5d8d3-5322-4c49-b9d6-da6e00be5d57

# %%
from azureml.core import Environment

# conda の yml ファイルより Environment を作成
env = Environment.from_conda_specification(
    name="diabetes-env",
    file_path="../environments/diabetes-env.yml"
)

# %%
env.docker.enabled = True

# %%
# Environment の登録
env.register(ws);

# %%
Environment.get(ws, 'diabetes-env')
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": true,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "diabetes-env",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "defaults",
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6",
#                 "pip",
#                 "notebook",
#                 "ipykernel",
#                 {
#                     "pip": [
#                         "interpret",
#                         "matplotlib",
#                         "azureml-defaults==1.19.0",
#                         "azureml-core==1.19.0",
#                         "azureml-widgets==1.19.0"
#                     ]
#                 }
#             ],
#             "name": "azureml_181610e2763c3ae45d46eb2c0b7a7a6f"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "3"
# }

# %%
Environment.list(ws)
# Out:
# {'pytorch-env': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "pytorch-env",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "defaults",
#                  "pytorch",
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6",
#                  "pip",
#                  "notebook",
#                  "ipykernel",
#                  {
#                      "pip": [
#                          "torch",
#                          "torchvision",
#                          "matplotlib",
#                          "azureml-sdk",
#                          "azureml-sdk[notebooks]"
#                      ]
#                  }
#              ],
#              "name": "azureml_d43b8e0e2f8c96372edb3a190bbaedf3"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "5"
#  },
#  'pytorch-env2': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "pytorch-env2",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "defaults",
#                  "pytorch",
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6",
#                  "pip",
#                  "notebook",
#                  "ipykernel",
#                  {
#                      "pip": [
#                          "torch",
#                          "torchvision",
#                          "matplotlib",
#                          "azureml-sdk",
#                          "azureml-sdk[notebooks]"
#                      ]
#                  }
#              ],
#              "name": "azureml_d43b8e0e2f8c96372edb3a190bbaedf3"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "1"
#  },
#  'titanic-env': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "titanic-env",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "defaults",
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6",
#                  "pip",
#                  "notebook",
#                  "ipykernel",
#                  {
#                      "pip": [
#                          "interpret",
#                          "matplotlib",
#                          "azureml-sdk==1.19.0",
#                          "azureml-widgets"
#                      ]
#                  }
#              ],
#              "name": "azureml_952e095053c090d5068a585fb0166b0f"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "1"
#  },
#  'diabetes-env': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "diabetes-env",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "defaults",
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6",
#                  "pip",
#                  "notebook",
#                  "ipykernel",
#                  {
#                      "pip": [
#                          "interpret",
#                          "matplotlib",
#                          "azureml-defaults==1.19.0",
#                          "azureml-core==1.19.0",
#                          "azureml-widgets==1.19.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_181610e2763c3ae45d46eb2c0b7a7a6f"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-Tutorial': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Tutorial",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "azureml-widgets==1.19.0",
#                          "azureml-pipeline-core==1.19.0",
#                          "azureml-pipeline-steps==1.19.0",
#                          "azureml-opendatasets==1.19.0",
#                          "azureml-automl-core==1.19.0",
#                          "azureml-automl-runtime==1.19.0",
#                          "azureml-train-automl-client==1.19.0",
#                          "azureml-train-automl-runtime==1.19.0",
#                          "azureml-train-automl==1.19.0",
#                          "azureml-train==1.19.0",
#                          "azureml-sdk==1.19.0",
#                          "azureml-interpret==1.19.0",
#                          "azureml-tensorboard==1.19.0",
#                          "azureml-mlflow==1.19.0",
#                          "mlflow",
#                          "sklearn-pandas"
#                      ]
#                  },
#                  "pandas",
#                  "numpy",
#                  "tqdm",
#                  "scikit-learn",
#                  "matplotlib"
#              ],
#              "name": "azureml_a1736710baabf05d37337a101fa8d6d1"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "60"
#  },
#  'AzureML-Minimal': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Minimal",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_f7834da2edca74e44d923018c85f9f6f"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-Chainer-5.1.0-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-cuda9.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Chainer-5.1.0-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "chainer==5.1.0",
#                          "cupy-cuda90==5.1.0",
#                          "mpi4py==3.0.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_572c1da11f9a94e3b7a6e6e6a2e63943"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-PyTorch-1.2-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.2-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "torch==1.2",
#                          "torchvision==0.4.0",
#                          "mkl==2018.0.3",
#                          "horovod==0.16.1",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_7e3429bb2b1ede094ce1947f29ee322f"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "43"
#  },
#  'AzureML-TensorFlow-1.12-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-1.12-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow==1.12",
#                          "horovod==0.15.2"
#                      ]
#                  }
#              ],
#              "name": "azureml_1cb37132b1778aa3c467af6d823e49bd"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "42"
#  },
#  'AzureML-TensorFlow-1.13-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-1.13-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow==1.13.1",
#                          "horovod==0.16.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_cf77ce9add884431274e1212cfdc4800"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "43"
#  },
#  'AzureML-PyTorch-1.1-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.1-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "torch==1.1",
#                          "torchvision==0.2.1",
#                          "mkl==2018.0.3",
#                          "horovod==0.16.1",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_6e145d82f92c27509a9b9e457edff086"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "43"
#  },
#  'AzureML-TensorFlow-1.10-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-1.10-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow==1.10",
#                          "horovod==0.15.2"
#                      ]
#                  }
#              ],
#              "name": "azureml_933357b2310f331c5e879b79bc6da6e5"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "43"
#  },
#  'AzureML-PyTorch-1.0-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.0-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "torch==1.0",
#                          "torchvision==0.2.1",
#                          "mkl==2018.0.3",
#                          "horovod==0.16.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_05cdd7fc9b238a159a456dc22c87f026"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-TensorFlow-1.12-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-cuda9.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-1.12-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow-gpu==1.12.0",
#                          "horovod==0.15.2"
#                      ]
#                  }
#              ],
#              "name": "azureml_f6e3ae7a94102e911365066d2221cd25"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-TensorFlow-1.13-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-cuda10.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-1.13-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow-gpu==1.13.1",
#                          "horovod==0.16.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_2e953a155ad9bb4934a5c5fc29c94461"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-Chainer-5.1.0-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Chainer-5.1.0-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "chainer==5.1.0",
#                          "mpi4py==3.0.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_9203abdb18d345501e3959f945e1eb62"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "43"
#  },
#  'AzureML-PyTorch-1.0-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.0-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "torch==1.0",
#                          "torchvision==0.2.1",
#                          "mkl==2018.0.3",
#                          "horovod==0.16.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_05cdd7fc9b238a159a456dc22c87f026"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "43"
#  },
#  'AzureML-Scikit-learn-0.20.3': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Scikit-learn-0.20.3",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "scikit-learn==0.20.3",
#                          "scipy==1.2.1",
#                          "joblib==0.13.2"
#                      ]
#                  }
#              ],
#              "name": "azureml_bcd70ff6547af73d6de4e3c50f2235b8"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "43"
#  },
#  'AzureML-PyTorch-1.2-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.2-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "torch==1.2",
#                          "torchvision==0.4.0",
#                          "mkl==2018.0.3",
#                          "horovod==0.16.1",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_7e3429bb2b1ede094ce1947f29ee322f"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-PyTorch-1.1-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.1-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "torch==1.1",
#                          "torchvision==0.2.1",
#                          "mkl==2018.0.3",
#                          "horovod==0.16.1",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_6e145d82f92c27509a9b9e457edff086"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-TensorFlow-1.10-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-cuda9.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-1.10-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow-gpu==1.10.0",
#                          "horovod==0.15.2"
#                      ]
#                  }
#              ],
#              "name": "azureml_dc023e98f7e8ec44741010682e15ee4f"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "44"
#  },
#  'AzureML-PyTorch-1.3-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.0-cudnn7-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.3-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "torch==1.3",
#                          "torchvision==0.4.1",
#                          "mkl==2018.0.3",
#                          "horovod==0.18.1",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_2cf46d0a4f94e54fc2a2377c20b861fa"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "41"
#  },
#  'AzureML-TensorFlow-2.0-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-2.0-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow==2.0",
#                          "horovod==0.18.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_21c7d56e994a09539dd5cc776f81ce65"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "41"
#  },
#  'AzureML-PyTorch-1.3-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.3-CPU",
# ...
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow-gpu==2.2.0",
#                          "horovod==0.19.5"
#                      ]
#                  }
#              ],
#              "name": "azureml_435a769981e94c0a7763212da4ffcfb3"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "11"
#  },
#  'AzureML-TensorFlow-2.2-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20201113.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-2.2-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "tensorflow==2.2.0",
#                          "horovod==0.19.5"
#                      ]
#                  }
#              ],
#              "name": "azureml_2ad4dcadddaf31412493a1dbb6c58d1a"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "11"
#  },
#  'AzureML-PyTorch-1.6-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu16.04:20201112.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.6-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.18.0.post1",
#                          "azureml-defaults==1.18.0",
#                          "azureml-telemetry==1.18.0",
#                          "azureml-train-restclients-hyperdrive==1.18.0",
#                          "azureml-train-core==1.18.0",
#                          "cmake==3.18.2",
#                          "torch==1.6.0",
#                          "torchvision==0.5.0",
#                          "mkl==2018.0.3",
#                          "horovod==0.20.0",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_9d2a515d5c77954f2d0562cc5eb8a1fc"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "10"
#  },
#  'AzureML-PyTorch-1.6-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04:20201112.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.6-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.18.0.post1",
#                          "azureml-defaults==1.18.0",
#                          "azureml-telemetry==1.18.0",
#                          "azureml-train-restclients-hyperdrive==1.18.0",
#                          "azureml-train-core==1.18.0",
#                          "cmake==3.18.2",
#                          "torch==1.6.0",
#                          "torchvision==0.5.0",
#                          "mkl==2018.0.3",
#                          "horovod==0.20.0",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_9d2a515d5c77954f2d0562cc5eb8a1fc"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "10"
#  },
#  'AzureML-Triton': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/aml-triton:20201209.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Triton",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.7.9",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults[async]",
#                          "azureml-contrib-services==1.19.0",
#                          "numpy",
#                          "inference-schema[numpy-support]",
#                          "grpcio-tools",
#                          "geventhttpclient",
#                          "https://developer.download.nvidia.com/compute/redist/tritonclient/tritonclient-2.4.0-py3-none-manylinux1_x86_64.whl"
#                      ]
#                  }
#              ],
#              "name": "azureml_b92a7b47de175f9e362d86b49657a9f1"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "9"
#  },
#  'AzureML-TensorFlow-2.3-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20201019.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-2.3-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.18.0.post1",
#                          "azureml-defaults==1.18.0",
#                          "azureml-telemetry==1.18.0",
#                          "azureml-train-restclients-hyperdrive==1.18.0",
#                          "azureml-train-core==1.18.0",
#                          "tensorflow==2.3.0",
#                          "cmake==3.18.2",
#                          "horovod==0.20.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_8e3321c66ae65459b91538aff75fe159"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "5"
#  },
#  'AzureML-TensorFlow-2.3-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04:20201112.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-2.3-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.18.0.post1",
#                          "azureml-defaults==1.18.0",
#                          "azureml-telemetry==1.18.0",
#                          "azureml-train-restclients-hyperdrive==1.18.0",
#                          "azureml-train-core==1.18.0",
#                          "tensorflow-gpu==2.3.0",
#                          "cmake==3.18.2",
#                          "horovod==0.20.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_60ad88840fdbe40e31e03ddbbc134dec"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "4"
#  },
#  'AzureML-DeepSpeed-0.3-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04\nENV DS_BUILD_OPS=1",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-DeepSpeed-0.3-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "pytorch",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "cudatoolkit-dev=10.1.243",
#                  "cudatoolkit=10.1",
#                  "pytorch==1.6.0",
#                  "torchvision==0.7.0",
#                  "gxx_linux-64",
#                  "pip<=20.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-telemetry==1.19.0",
#                          "azureml-train-restclients-hyperdrive==1.19.0",
#                          "azureml-train-core==1.19.0",
#                          "azureml-mlflow==1.19.0",
#                          "azureml-dataprep",
#                          "cmake==3.18.2",
#                          "mkl==2018.0.3",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1",
#                          "matplotlib",
#                          "boto3",
#                          "h5py",
#                          "sklearn",
#                          "scipy",
#                          "pillow",
#                          "tqdm",
#                          "cupy-cuda101",
#                          "mpi4py",
#                          "deepspeed==0.3.*"
#                      ]
#                  }
#              ],
#              "name": "azureml_cbae9014d00ec9d2c3e9c1f2c3c53f67"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "2"
#  }}
